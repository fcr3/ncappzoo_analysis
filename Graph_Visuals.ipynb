# %%
import requests
import pandas as pd
import datetime as dt
import os
import plotly.graph_objects as go
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from scipy.interpolate import interp1d
import statsmodels.api as sm
import numpy as np

# %%
# Change the file names to 
viewsfile = 'master_tables/updated_views_2019-12-06_11-56-22.csv'
clonesfile = 'master_tables/updated_clones_2019-12-06_11-56-22.csv'
views = pd.read_csv(viewsfile)
clones = pd.read_csv(clonesfile)

# %%
def reg_line_pts(df, col2):
    xaxis = [x for x in range(len(df))]
    yaxis = df[col2].values
    
    # calculation of slope using pearsonr for non-gaussian distributions
    corr, _ = pearsonr(xaxis, yaxis)
    m = corr * (np.std(yaxis) / np.std(xaxis))
    
    # calculation of y-intercept based on means
    yint = np.mean(yaxis) - m * np.mean(xaxis)
    
    predictions = [m*i + yint for i in xaxis]
    return predictions

def reg_line_pts2(df, col2):
    data = pd.DataFrame({
        'x': [x for x in range(len(df))],
        'y': [x for x in df[col2].values]
    })
    X = data.iloc[:, 0].values.reshape(-1, 1)
    Y = data.iloc[:, 1].values.reshape(-1, 1)
    reg = LinearRegression()
    reg.fit(X, Y)
    return reg.predict(X).T[0]

def lowess_line_pts(df, col2):
    data = pd.DataFrame({
        'x': [x for x in range(len(df))],
        'y': [x for x in df[col2].values]
    })
    X = data.iloc[:, 0].values
    Y = data.iloc[:, 1].values
    
    # lowess will return our "smoothed" data with a y value for at every x-value
    lowess = sm.nonparametric.lowess(Y, X, frac=.2)

    # unpack the lowess smoothed points to their values
    lowess_x = list(zip(*lowess))[0]
    lowess_y = list(zip(*lowess))[1]
    
    # Interpolation
    f = interp1d(lowess_x, lowess_y, bounds_error=False)
    xnew = [x/10. for x in X]
    ynew = f(xnew)
    return lowess_y

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=views['count'],
                         mode='lines+markers', name='Actual Points'))
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=reg_line_pts2(views, 'count'), 
                         mode='lines+markers', name='Regression'))
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=lowess_line_pts(views, 'count'), 
                         mode='lines+markers', name='LOWESS'))
fig.update_layout(title='Views Per Day', xaxis_title='Date', yaxis_title='Count')
fig.show()
# Out:
# <div>
#
#
#             <div id="c25c13d9-064e-4d68-98d9-67eb4e60eef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c25c13d9-064e-4d68-98d9-67eb4e60eef2")) {
#                     Plotly.newPlot(
#                         'c25c13d9-064e-4d68-98d9-67eb4e60eef2',
#                         [{"mode": "lines+markers", "name": "Actual Points", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09", "2019-11-10", "2019-11-11", "2019-11-12", "2019-11-14", "2019-11-15", "2019-11-16", "2019-11-17", "2019-11-18", "2019-11-19", "2019-11-20", "2019-11-21", "2019-11-22", "2019-11-23", "2019-11-24", "2019-11-25", "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06"], "y": [80, 80, 170, 260, 270, 400, 260, 80, 70, 370, 450, 500, 450, 300, 240, 240, 350, 470, 350, 610, 400, 230, 180, 320, 340, 400, 320, 250, 160, 100, 410, 230, 500, 360, 270, 130, 100, 200, 430, 420, 510, 340, 220, 130, 330, 340, 350, 300, 350, 70, 310, 360, 310, 300, 410, 387, 213, 155, 284, 467, 207, 348, 320, 131, 225, 351, 370, 612, 413, 279, 154, 274, 328, 309, 253, 301, 155, 127, 109, 268, 291, 267, 285, 367, 189, 200, 444, 305, 390, 297, 273, 140, 144, 299, 286, 247, 292, 207, 133, 366, 346, 394, 356, 354, 232, 107, 425, 263, 360, 253, 209, 151, 403, 416, 410, 328, 344, 242, 144, 423, 280, 303, 204, 251, 118, 130, 377, 264, 417, 286, 203]}, {"mode": "lines+markers", "name": "Regression", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "20 ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=views['uniques'],
                         mode='lines+markers', name='Actual Points'))
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=reg_line_pts2(views, 'uniques'), 
                         mode='lines+markers', name='Trendline'))
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=lowess_line_pts(views, 'uniques'), 
                         mode='lines+markers', name='LOWESS'))
fig.update_layout(title='Unique Views Per Day', xaxis_title='Date', yaxis_title='Unique Count')
fig.show()
# Out:
# <div>
#
#
#             <div id="3cad2f90-1e27-4490-b915-ced6583b298d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3cad2f90-1e27-4490-b915-ced6583b298d")) {
#                     Plotly.newPlot(
#                         '3cad2f90-1e27-4490-b915-ced6583b298d',
#                         [{"mode": "lines+markers", "name": "Actual Points", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09", "2019-11-10", "2019-11-11", "2019-11-12", "2019-11-14", "2019-11-15", "2019-11-16", "2019-11-17", "2019-11-18", "2019-11-19", "2019-11-20", "2019-11-21", "2019-11-22", "2019-11-23", "2019-11-24", "2019-11-25", "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06"], "y": [25, 35, 56, 70, 50, 70, 50, 20, 19, 57, 58, 63, 72, 50, 40, 27, 63, 85, 57, 60, 72, 48, 32, 70, 65, 80, 65, 50, 35, 30, 65, 55, 70, 60, 56, 25, 23, 55, 52, 65, 60, 75, 65, 33, 78, 78, 65, 65, 57, 25, 33, 83, 66, 60, 66, 71, 43, 30, 71, 79, 49, 61, 79, 43, 53, 86, 100, 102, 79, 80, 49, 46, 85, 80, 86, 88, 56, 38, 35, 82, 89, 93, 99, 93, 49, 55, 114, 87, 92, 92, 73, 46, 47, 78, 103, 82, 79, 50, 39, 90, 93, 106, 92, 78, 50, 47, 95, 97, 100, 93, 55, 45, 96, 110, 96, 87, 100, 53, 45, 97, 99, 91, 84, 74, 43, 52, 90, 84, 99, 91, 74]}, {"mode": "lines+markers", "name": "Trendline", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-0 ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=clones['yr_mo_day'], y=clones['count'],
                         mode='lines+markers', name='Actual Points'))
fig.add_trace(go.Scatter(x=clones['yr_mo_day'], y=reg_line_pts2(clones, 'count'), 
                         mode='lines+markers', name='Trendline'))
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=lowess_line_pts(clones, 'count'), 
                         mode='lines+markers', name='LOWESS'))
fig.update_layout(title='Clones Per Day', xaxis_title='Date', yaxis_title='Counts')
fig.show()
# Out:
# <div>
#
#
#             <div id="1e84e4eb-601f-4e4f-8b7b-dcf90dbef06b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e84e4eb-601f-4e4f-8b7b-dcf90dbef06b")) {
#                     Plotly.newPlot(
#                         '1e84e4eb-601f-4e4f-8b7b-dcf90dbef06b',
#                         [{"mode": "lines+markers", "name": "Actual Points", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09", "2019-11-10", "2019-11-11", "2019-11-12", "2019-11-14", "2019-11-15", "2019-11-16", "2019-11-17", "2019-11-18", "2019-11-19", "2019-11-20", "2019-11-21", "2019-11-22", "2019-11-23", "2019-11-24", "2019-11-25", "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06"], "y": [11, 4, 17, 28, 16, 28, 10, 16, 10, 30, 29, 32, 21, 34, 34, 33, 44, 48, 48, 42, 33, 24, 20, 20, 20, 30, 23, 17, 16, 14, 44, 24, 27, 30, 20, 16, 15, 32, 24, 23, 30, 22, 22, 15, 26, 26, 24, 43, 43, 40, 20, 19, 32, 33, 25, 37, 28, 20, 33, 33, 25, 22, 14, 18, 13, 29, 24, 37, 31, 28, 13, 16, 18, 28, 21, 21, 24, 24, 21, 37, 31, 26, 18, 34, 24, 23, 26, 30, 33, 44, 24, 37, 15, 31, 29, 24, 24, 8, 8, 32, 29, 43, 34, 27, 35, 26, 31, 33, 28, 23, 32, 14, 36, 25, 19, 25, 27, 19, 16, 27, 35, 31, 43, 27, 15, 23, 43, 27, 17, 26, 16]}, {"mode": "lines+markers", "name": "Trendline", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-1 ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=clones['yr_mo_day'], y=clones['uniques'],
                         mode='lines+markers', name='Actual Points'))
fig.add_trace(go.Scatter(x=clones['yr_mo_day'], y=reg_line_pts2(clones, 'uniques'), 
                         mode='lines+markers', name='Trendline'))
fig.add_trace(go.Scatter(x=views['yr_mo_day'], y=lowess_line_pts(clones, 'uniques'), 
                         mode='lines+markers', name='LOWESS'))
fig.update_layout(title='Unique Clones Per Day', xaxis_title='Date', yaxis_title='Unique Counts')
fig.show()
# Out:
# <div>
#
#
#             <div id="c32aca5d-879b-47f1-8269-b771171183b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c32aca5d-879b-47f1-8269-b771171183b5")) {
#                     Plotly.newPlot(
#                         'c32aca5d-879b-47f1-8269-b771171183b5',
#                         [{"mode": "lines+markers", "name": "Actual Points", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09", "2019-11-10", "2019-11-11", "2019-11-12", "2019-11-14", "2019-11-15", "2019-11-16", "2019-11-17", "2019-11-18", "2019-11-19", "2019-11-20", "2019-11-21", "2019-11-22", "2019-11-23", "2019-11-24", "2019-11-25", "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06"], "y": [7, 4, 10, 16, 10, 14, 7, 8, 7, 14, 15, 17, 15, 17, 18, 19, 22, 20, 23, 22, 20, 18, 13, 17, 17, 24, 21, 16, 17, 13, 27, 20, 19, 24, 19, 13, 15, 23, 20, 18, 19, 10, 11, 11, 17, 17, 20, 32, 32, 28, 12, 12, 27, 24, 22, 25, 21, 14, 29, 20, 21, 19, 13, 16, 11, 24, 16, 28, 28, 23, 12, 14, 12, 17, 20, 19, 19, 20, 14, 20, 26, 24, 15, 24, 16, 18, 22, 25, 28, 35, 20, 24, 10, 18, 25, 17, 20, 7, 8, 21, 23, 28, 28, 23, 23, 16, 27, 24, 20, 19, 22, 11, 23, 20, 18, 23, 19, 16, 15, 19, 26, 24, 31, 15, 10, 15, 26, 20, 16, 20, 11]}, {"mode": "lines+markers", "name": "Trendline", "type": "scatter", "x": ["2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09 ...
