# %%
import pandas as pd

# %%
pd = pd.read_csv('../picture_parsed_data/ref_clones_2019-10-26.csv')

# %%
pd
# Out:
#                timestamp  count  uniques  day  mo    yr  \
# 0   2019-07-27T00:00:00Z     11        7   27   7  2019
# 1   2019-07-28T00:00:00Z      4        4   28   7  2019
# 2   2019-07-29T00:00:00Z     17       10   29   7  2019
# 3   2019-07-30T00:00:00Z     28       16   30   7  2019
# 4   2019-07-31T00:00:00Z     16       10   31   7  2019
# 5   2019-08-01T00:00:00Z     28       14    1   8  2019
# 6   2019-08-02T00:00:00Z     10        7    2   8  2019
# 7   2019-08-03T00:00:00Z     16        8    3   8  2019
# 8   2019-08-04T00:00:00Z     10        7    4   8  2019
# 9   2019-08-05T00:00:00Z     30       14    5   8  2019
# 10  2019-08-06T00:00:00Z     29       15    6   8  2019
# 11  2019-08-07T00:00:00Z     32       17    7   8  2019
# 12  2019-08-08T00:00:00Z     21       15    8   8  2019
# 13  2019-08-09T00:00:00Z     34       17    9   8  2019
# 14  2019-08-10T00:00:00Z     34       18   10   8  2019
# 15  2019-08-11T00:00:00Z     33       19   11   8  2019
# ...
